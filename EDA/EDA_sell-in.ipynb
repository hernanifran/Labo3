# %%
import pandas as pd
import numpy as np
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
df = pd.read_csv('sell-in.txt/sell-in.txt', sep='\t')
df.shape
# Out:
# (2945818, 7)

# %%
df.head()
# Out:
#    periodo  customer_id  product_id  plan_precios_cuidados  cust_request_qty
# 0  201701      10234        20524              0                    2         \
# 1  201701      10032        20524              0                    1
# 2  201701      10217        20524              0                    1
# 3  201701      10125        20524              0                    1
# 4  201701      10012        20524              0                   11
#
#    cust_request_tn    tn
# 0      0.05300      0.05300
# 1      0.13628      0.13628
# 2      0.03028      0.03028
# 3      0.02271      0.02271
# 4      1.54452      1.54452

# %%
df2=pd.DataFrame(df)
df2
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados
# 0        201701      10234        20524              0            \
# 1        201701      10032        20524              0
# 2        201701      10217        20524              0
# 3        201701      10125        20524              0
# 4        201701      10012        20524              0
# ...          ...          ...         ...                    ...
# 2945813  201912      10105        20853              0
# 2945814  201912      10092        20853              0
# 2945815  201912      10006        20853              0
# 2945816  201912      10018        20853              0
# 2945817  201912      10020        20853              0
#
#          cust_request_qty  cust_request_tn    tn
# 0                2             0.05300      0.05300
# 1                1             0.13628      0.13628
# 2                1             0.03028      0.03028
# 3                1             0.02271      0.02271
# 4               11             1.54452      1.54452
# ...                   ...              ...      ...
# 2945813          1             0.02230      0.02230
# 2945814          1             0.00669      0.00669
# 2945815          7             0.02898      0.02898
# 2945816          4             0.01561      0.01561
# 2945817          2             0.01561      0.01561
#
# [2945818 rows x 7 columns]

# %%
# Crear una instancia de AutoViz
AV = AutoViz_Class()

# Generar visualizaciones automáticas
df_viz = AV.AutoViz(df2, sep='\t')

# %matplotlib inline
# Out:
#     Since nrows is smaller than dataset, loading random sample of 150000 rows into pandas...
# Shape of your Data Set loaded: (150000, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  4
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Since Number of Rows in data 150000 exceeds maximum, randomly sampling 150000 rows for EDA...
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_edfaf_row0_col0, #T_edfaf_row0_col2, #T_edfaf_row0_col5, #T_edfaf_row1_col0, #T_edfaf_row1_col2, #T_edfaf_row1_col5, #T_edfaf_row2_col0, #T_edfaf_row2_col2, #T_edfaf_row2_col5, #T_edfaf_row3_col0, #T_edfaf_row3_col2, #T_edfaf_row3_col5, #T_edfaf_row4_col0, #T_edfaf_row4_col2, #T_edfaf_row4_col5, #T_edfaf_row5_col0, #T_edfaf_row5_col2, #T_edfaf_row5_col5, #T_edfaf_row6_col0, #T_edfaf_row6_col2, #T_edfaf_row6_col5 {
#   font-family: Segoe UI;
# }
# #T_edfaf_row0_col1, #T_edfaf_row1_col1, #T_edfaf_row2_col1, #T_edfaf_row3_col1, #T_edfaf_row3_col3, #T_edfaf_row3_col4, #T_edfaf_row4_col1, #T_edfaf_row4_col3, #T_edfaf_row4_col4, #T_edfaf_row5_col1, #T_edfaf_row5_col3, #T_edfaf_row5_col4, #T_edfaf_row6_col1, #T_edfaf_row6_col3, #T_edfaf_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_edfaf_row0_col3, #T_edfaf_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_edfaf_row1_col3 {
#   background-color: #ffede5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_edfaf_row1_col4 {
#   background-color: #ffece4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_edfaf_row2_col3 {
#   background-color: #fee5d8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_edfaf_row2_col4 {
#   background-color: #fee4d8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_edfaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edfaf_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_edfaf_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_edfaf_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_edfaf_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_edfaf_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_edfaf_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edfaf_level0_row0" class="row_heading level0 row0" >periodo</th>
#       <td id="T_edfaf_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_edfaf_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_edfaf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_edfaf_row0_col3" class="data row0 col3" >201701.000000</td>
#       <td id="T_edfaf_row0_col4" class="data row0 col4" >201912.000000</td>
#       <td id="T_edfaf_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row1" class="row_heading level0 row1" >customer_id</th>
#       <td id="T_edfaf_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_edfaf_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_edfaf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_edfaf_row1_col3" class="data row1 col3" >10001.000000</td>
#       <td id="T_edfaf_row1_col4" class="data row1 col4" >10635.000000</td>
#       <td id="T_edfaf_row1_col5" class="data row1 col5" >Column has 328 outliers greater than upper bound (10586.50) or lower than lower bound(9734.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row2" class="row_heading level0 row2" >product_id</th>
#       <td id="T_edfaf_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_edfaf_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_edfaf_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_edfaf_row2_col3" class="data row2 col3" >20001.000000</td>
#       <td id="T_edfaf_row2_col4" class="data row2 col4" >21292.000000</td>
#       <td id="T_edfaf_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row3" class="row_heading level0 row3" >plan_precios_cuidados</th>
#       <td id="T_edfaf_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_edfaf_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_edfaf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_edfaf_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_edfaf_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_edfaf_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row4" class="row_heading level0 row4" >cust_request_qty</th>
#       <td id="T_edfaf_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_edfaf_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_edfaf_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_edfaf_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_edfaf_row4_col4" class="data row4 col4" >90.000000</td>
#       <td id="T_edfaf_row4_col5" class="data row4 col5" >Column has 15893 outliers greater than upper bound (3.50) or lower than lower bound(-0.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row5" class="row_heading level0 row5" >cust_request_tn</th>
#       <td id="T_edfaf_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_edfaf_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_edfaf_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_edfaf_row5_col3" class="data row5 col3" >0.000100</td>
#       <td id="T_edfaf_row5_col4" class="data row5 col4" >407.022250</td>
#       <td id="T_edfaf_row5_col5" class="data row5 col5" >Column has 22311 outliers greater than upper bound (0.38) or lower than lower bound(-0.21). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_edfaf_level0_row6" class="row_heading level0 row6" >tn</th>
#       <td id="T_edfaf_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_edfaf_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_edfaf_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_edfaf_row6_col3" class="data row6 col3" >0.000100</td>
#       <td id="T_edfaf_row6_col4" class="data row6 col4" >379.442700</td>
#       <td id="T_edfaf_row6_col5" class="data row6 col5" >Column has 22263 outliers greater than upper bound (0.38) or lower than lower bound(-0.21). Cap them or remove them., Column has a high correlation with ['cust_request_tn']. Consider dropping one of them.</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 15 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
# Preprocesado de datos (estableciendo índice y frecuencia)
# ==============================================================================
datos = df2
datos['periodo'] = pd.to_datetime(datos['periodo'], format='%Y%m')
#datos = datos.set_index('periodo')

# Agregar una nueva columna 'periodo_mes' que contenga solo el año y el mes
df2['periodo_mes'] = df2['periodo'].dt.to_period('M')

# Establecer 'periodo_mes' como el índice del DataFrame
df2 = df2.set_index('periodo_mes')

#datos = datos.asfreq('H')
datos = datos.sort_index()
datos.head()
# Out:
#    periodo    customer_id  product_id  plan_precios_cuidados
# 0 2017-01-01     10234        20524              0            \
# 1 2017-01-01     10032        20524              0
# 2 2017-01-01     10217        20524              0
# 3 2017-01-01     10125        20524              0
# 4 2017-01-01     10012        20524              0
#
#    cust_request_qty  cust_request_tn    tn    periodo_mes
# 0          2             0.05300      0.05300    2017-01
# 1          1             0.13628      0.13628    2017-01
# 2          1             0.03028      0.03028    2017-01
# 3          1             0.02271      0.02271    2017-01
# 4         11             1.54452      1.54452    2017-01

# %%
# Generar visualizaciones automáticas
df_viz = AV.AutoViz(datos, sep='\t')

# %matplotlib inline
# Out:
#     Since nrows is smaller than dataset, loading random sample of 150000 rows into pandas...
# Shape of your Data Set loaded: (150000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# periodo_mes of type=period[M] is not classified
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
# No of columns classified 7 does not match 8 total cols. Continuing...
#  Missing columns = ['periodo_mes']
#         No variables removed since no ID or low-information variables found in data set
# Since Number of Rows in data 150000 exceeds maximum, randomly sampling 150000 rows for EDA...
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# periodo_mes of type=period[M] is not classified
# No of columns classified 7 does not match 8 total cols. Continuing...
#  Missing columns = ['periodo_mes']
# <style type="text/css">
# #T_8926b_row0_col0, #T_8926b_row0_col2, #T_8926b_row0_col3, #T_8926b_row0_col4, #T_8926b_row0_col5, #T_8926b_row1_col0, #T_8926b_row1_col2, #T_8926b_row1_col3, #T_8926b_row1_col4, #T_8926b_row1_col5, #T_8926b_row2_col0, #T_8926b_row2_col2, #T_8926b_row2_col3, #T_8926b_row2_col4, #T_8926b_row2_col5, #T_8926b_row3_col0, #T_8926b_row3_col2, #T_8926b_row3_col3, #T_8926b_row3_col4, #T_8926b_row3_col5, #T_8926b_row4_col0, #T_8926b_row4_col2, #T_8926b_row4_col3, #T_8926b_row4_col4, #T_8926b_row4_col5, #T_8926b_row5_col0, #T_8926b_row5_col2, #T_8926b_row5_col3, #T_8926b_row5_col4, #T_8926b_row5_col5, #T_8926b_row6_col0, #T_8926b_row6_col2, #T_8926b_row6_col3, #T_8926b_row6_col4, #T_8926b_row6_col5, #T_8926b_row7_col0, #T_8926b_row7_col2, #T_8926b_row7_col3, #T_8926b_row7_col4, #T_8926b_row7_col5 {
#   font-family: Segoe UI;
# }
# #T_8926b_row0_col1, #T_8926b_row1_col1, #T_8926b_row2_col1, #T_8926b_row3_col1, #T_8926b_row4_col1, #T_8926b_row5_col1, #T_8926b_row6_col1, #T_8926b_row7_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_8926b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8926b_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_8926b_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_8926b_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_8926b_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_8926b_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_8926b_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8926b_level0_row0" class="row_heading level0 row0" >periodo</th>
#       <td id="T_8926b_row0_col0" class="data row0 col0" >datetime64[ns]</td>
#       <td id="T_8926b_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_8926b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8926b_row0_col3" class="data row0 col3" ></td>
#       <td id="T_8926b_row0_col4" class="data row0 col4" ></td>
#       <td id="T_8926b_row0_col5" class="data row0 col5" >Possible date-time colum: transform before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row1" class="row_heading level0 row1" >customer_id</th>
#       <td id="T_8926b_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8926b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_8926b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_8926b_row1_col3" class="data row1 col3" >10001.000000</td>
#       <td id="T_8926b_row1_col4" class="data row1 col4" >10635.000000</td>
#       <td id="T_8926b_row1_col5" class="data row1 col5" >Column has 328 outliers greater than upper bound (10586.50) or lower than lower bound(9734.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row2" class="row_heading level0 row2" >product_id</th>
#       <td id="T_8926b_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_8926b_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_8926b_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_8926b_row2_col3" class="data row2 col3" >20001.000000</td>
#       <td id="T_8926b_row2_col4" class="data row2 col4" >21292.000000</td>
#       <td id="T_8926b_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row3" class="row_heading level0 row3" >plan_precios_cuidados</th>
#       <td id="T_8926b_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_8926b_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_8926b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_8926b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_8926b_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_8926b_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row4" class="row_heading level0 row4" >cust_request_qty</th>
#       <td id="T_8926b_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_8926b_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_8926b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_8926b_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_8926b_row4_col4" class="data row4 col4" >90.000000</td>
#       <td id="T_8926b_row4_col5" class="data row4 col5" >Column has 15893 outliers greater than upper bound (3.50) or lower than lower bound(-0.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row5" class="row_heading level0 row5" >cust_request_tn</th>
#       <td id="T_8926b_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_8926b_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_8926b_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_8926b_row5_col3" class="data row5 col3" >0.000100</td>
#       <td id="T_8926b_row5_col4" class="data row5 col4" >407.022250</td>
#       <td id="T_8926b_row5_col5" class="data row5 col5" >Column has 22311 outliers greater than upper bound (0.38) or lower than lower bound(-0.21). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row6" class="row_heading level0 row6" >tn</th>
#       <td id="T_8926b_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_8926b_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_8926b_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_8926b_row6_col3" class="data row6 col3" >0.000100</td>
#       <td id="T_8926b_row6_col4" class="data row6 col4" >379.442700</td>
#       <td id="T_8926b_row6_col5" class="data row6 col5" >Column has 22263 outliers greater than upper bound (0.38) or lower than lower bound(-0.21). Cap them or remove them., Column has a high correlation with ['cust_request_tn']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_8926b_level0_row7" class="row_heading level0 row7" >periodo_mes</th>
#       <td id="T_8926b_row7_col0" class="data row7 col0" >period[M]</td>
#       <td id="T_8926b_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_8926b_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_8926b_row7_col3" class="data row7 col3" ></td>
#       <td id="T_8926b_row7_col4" class="data row7 col4" ></td>
#       <td id="T_8926b_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 13 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
